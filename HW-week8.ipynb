# %% [markdown]
# # Data Wrangling HW

# %% [markdown]
# >Brynn O'Toole

# %% [markdown]
# ### Quiz Questions

# %% [markdown]
# 1. import pandas as pd

# %% [markdown]
# 2. df = pd.read_csv("data.csv")

# %% [markdown]
# 3. df.head(5)

# %% [markdown]
# 4. df.shape

# %% [markdown]
# 5. df.columns

# %% [markdown]
# 6. df.dftypes

# %% [markdown]
# 7. filtereddf = df[df['A] > 5']

# %% [markdown]
# 8. dfAB = df[["A", "B"]]

# %% [markdown]
# 9. df.rename(columns={'A':'Alpha'}, inplace=True)
# df.columns

# %% [markdown]
# 10. df = df.replace({'999': np.nan})

# %% [markdown]
# 11. complete_data_df = df.dropna()

# %% [markdown]
# 12. df_filled = df.ffillna(0)

# %% [markdown]
# 13. df['A'].mean()

# %% [markdown]
# 14. df['C'] = df['A'] + df['B']

# %% [markdown]
# 15. df.to_csv('output.csv', index=False)
