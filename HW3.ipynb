# %% [markdown]
# ## HW: Ethics and Privacy

# %% [markdown]
# >Name: Brynn O'Toole

# %% [markdown]
# ### Question 1: Misuse of Health Data

# %% [markdown]
# In rhe 1980s, the Nuu-chah-nulth people on Vancouver Island donated over 800 vials of blood to researchers at the University of British Columbia to study rheumatoid arthritis, a condition prevalent in their community. The researcher who collected the samples left his institution, taking the samples with him. The researcher shared them with other researchers for studies unrelated to the original consent, specifically for genetic anthropology, migration patterns, and studies on retroviruses. The donors were not informed that their samples were used for these extra studies, causing a profound breach of trust and highlighting a disregard for informed consent.

# %% [markdown]
# ### Question 2: Breaches in Health Data

# %% [markdown]
# In 2024, a major ransonware attacked on Change Healthcare, a UnitedHealth Group subsidiary, destroyed payment systems across the US healthcare system exposing people's senstitive personal and medical data.  This is one of the largest disruptions in recent history impacting 192.7 million people. This was triggered by a alack of multi factor authentication, so it could have been prevented by implementing this way of authentication.

# %% [markdown]
# ### Question 3: Bias in Health Data

# %% [markdown]
# AI diagnostic tools for dermatological conditions are often trained primarily on lighter skin tones, leading to lower accuracy in identifying skin cancers on darker skin. To prevent this from happening AI needs to be trained on all skin tones to make it more accurate and reliable at detecting skin cancer for everyone who coudl be affected.

# %% [markdown]
# ### Question 4: Anonymization

# %% [markdown]
# Generalization is an example of anonymization. This is when you replace exact ages with age ranges like 30-40.

# %% [markdown]
# ### Question 5: Pro Forma

# %% [markdown]
# I found a template on Prisma Health Academics and it includes the purpose of data collection, procedures, risks, privacy protections, and voluntary withdrawal rights. It outlines how data will be used, stored, and shared with researchers, ensuring compliance with privacy laws.

# %% [markdown]
# ### Quiz Questions

# %% [markdown]
# 1. The primary goal of data anonymization is to make it extremely difficult, if not impossible to identify the individual's data, but still allowing the data to be useful for analysis or research.

# %% [markdown]
# 2. ASU wanted to conduct research about the Havadupai Tribe's high prevelance of Type 2 diabetes. Blood samples were collected with the notion that they were only going to be used to find the genetic basis of the diabetes epidemic within their own community. Without the tribes consent, researchers used blood samples for more studies on schizophrenia, metabolic disorders, and tracing the tribe's geographical origin. Because the researchers did not ask for consent to further their research topics, naturally the tribe felt violated and betrayed so they sued the ASU board and in turn got $700,000 in damages, blood samples were returned, etc.

# %% [markdown]
# 3. The largest health data breach in history was when Anthem Inc, one of the largest health insurance companies in the US, got hacked.

# %% [markdown]
# 4. The pulse oximeter controversy is about how these devices that measure oxygen levels are nearly three times more likely to miss hypoxemia, or low blood oxygen levels, in Black patients compared to White patients.

# %% [markdown]
# 5. The role of the IRB is to uphold the rights and welfare of research patients making sure all research done is ethically.

# %% [markdown]
# 6. Spreadsheet software is ideal for small scale and flexible analysis,  while database software is required for secure, scalable, and structured management of large clinical datasets.

# %% [markdown]
# 7. Conflicts of interests in public health research are when people or groups have different opinions about how research should or should not be done. These conflicts can be a result of different morals, beliefs, cultural traditions, or religons and be significant threats to the integrity of research.

# %% [markdown]
# 8. Informed consent is when individuals are required to be provided with information to make educated decisions about their role in research.

# %% [markdown]
# 9. Data masking is replacing information that can help outsiders identity a person.

# %% [markdown]
# 10. K-anonymity is when you group data in a way that each group contains k records which makes it difficult to single out individuals.

# %% [markdown]
# 11. Conflicts of interest can threaten the integreity of public health research because they can lead to breaches of trust, objectivity loss, and biased results.

# %% [markdown]
# 12. The first step in managing conflicts of interest is transparency, disclosing any potential conflicts of interests.

# %% [markdown]
# 13. Independent oversight can include having a separate committe review research proposals for potential conflicts, monitoring ongoing research, and reviewing findings before publication.

# %% [markdown]
# 14. Avoidance is one way of mitigating conflicts of interest. It basically just means to not participate in studies that may have conflicts of interest.

# %% [markdown]
# 15. One potential impact is loss of public trust which can lead to no one wanting to participate in future studies.
