# %% [markdown]
# #### Spreadsheets vs. Databases

# %% [markdown]
# >Name: Brynn O'Toole

# %% [markdown]
# ## Quiz Questions

# %% [markdown]
# 1. Spreadsheets are mainly for calculations and small datasets, while databases are used to manage and manipulate large datasets.

# %% [markdown]
# 2. The advantages of using spreadsheets are that they provide a user friendly space for data entry and manipulation as it allows users to organize data in rows and columns, do calculations, create charts, and use data analysis tools. A disadvanatge is that they are not equipped for using large or complex datasets.

# %% [markdown]
# 3. An advantage of using databases is that they are designed to handle larger and more complex datasets, but they are higher in complexity for setup, maintenance, and usage.

# %% [markdown]
# 4. A spreadsheet is used to store, manipulate, and analyze data in tabular form using formulas, charts, etc.

# %% [markdown]
# 5. Health databases are using for clinical decision supprt, research, public health reporting, patient care management, and health policy development.

# %% [markdown]
# 6. Spreadsheets and data bases are  both used for data storage, sorting, filtering, and reporting.

# %% [markdown]
# 7. Databases and spreadsheets both can not perform effectively on unstructured, untidy data.

# %% [markdown]
# 8. Spreadsheets can do cell by cell calculations and free form data entry.

# %% [markdown]
# 9. Databases can handle millions of rows and enforce very strict data integrity.

# %% [markdown]
# 10. Both databases and spreadsheets can both do calculations, data analysis, data storage, sorting, filtering, and reporting
