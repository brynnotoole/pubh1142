# %% [markdown]
# # INTRODUCTION TO PYTHON

# %% [markdown]
# >Name: Brynn O'Toole

# %% [markdown]
# ## Tasks

# %%
import numpy
import pandas
import scipy.stats as stats

# %% [markdown]
# ### Task 1

# %%
# Calculate a solution to the expression below. ((6+4)×2)/10
result = ((6 + 4) * 2) / 10
print(result)
# Out:
# 2.0

# %% [markdown]
# ### Task 2

# %%
# Create code such that x = 5 and y = x. Then let x = 7. Determine the value of y.
x = 5
y = x
x = 7
print(y)
# Out:
# 5

# %% [markdown]
# ### Task 3

# %%
# Generate a for loop that print the square of each integer from 0 to 5 to the screen.
for i in range(6):
    print(i ** 2)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# ### Task 4

# %%
# Initialize the variable i by assigning it the value 0. This overwrites the current value stored in i as used above. Print the square of each 1 -unit increment in i, while i remains less than  10.
i = 0
while i < 10:
    print(i ** 2)
    i += 1
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %% [markdown]
# ## Quiz Questions

# %% [markdown]
# ### Question 1

# %%
result = 3 * 8
print(result)
# Out:
# 24

# %%
result = (33 + 7)/5
print(result)
# Out:
# 8.0

# %% [markdown]
# ### Question 2

# %% [markdown]
# The code `1+2` returns an integer and the code `1+2.` returns a floating point number. The reason is that the decimal point in the second code is interpreted as a floating point number and the integer data type in Python cannot hold a floating point number.

# %% [markdown]
# ### Question 3

# %%
for n in range(1, 6):
    print(n**2)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
[print(n**2) for n in range(1,6)];
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
i = 1

while i**2 < 1000:
    i += 1

print(i)
# Out:
# 32
